# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
from Tools import cargar_datos_mip
from Tools import cargar_datos_Mercatoria
from Tools import yogurt_data
datos_completos = cargar_datos_mip()
data_mer = cargar_datos_Mercatoria()

# %%
from graph import grafica_promedio_basica

fig = grafica_promedio_basica(datos_completos)
fig.show()

# %%
from graph import g_moda_pais_comparativa
fig_comparativa = g_moda_pais_comparativa(datos_completos, data_mer)
fig_comparativa.show()

# %%
from graph import barr_comp
figura = barr_comp(datos_completos, data_mer)
figura.show()

# %%
from graph import grafica_heatmap

fig = grafica_heatmap(data_mer)
fig.show()
# Out:
# {'El toque': {'eltoque': [{'USD': 440.0, 'source': 'eltoque', 'date': '2025-10-01'}, {'USD': 450.0, 'source': 'eltoque', 'date': '2025-12-06'}, {'USD': 445.0, 'source': 'eltoque', 'date': '2025-12-07'}, {'USD': 445.0, 'source': 'eltoque', 'date': '2025-12-08'}, {'USD': 445.0, 'source': 'eltoque', 'date': '2025-12-08'}, {'USD': 445.0, 'source': 'eltoque', 'date': '2025-12-09'}, {'USD': 445.0, 'source': 'eltoque', 'date': '2025-12-10'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-11'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-12'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-13'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-14'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-16'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-17'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-18'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-18'}, {'USD': 440.0, 'source': 'eltoque', 'date': '2025-12-19'}, {'USD': 440.0, 'source': 'el
# ...

# %%
from graph import yogurt_flavor_bar
yogurt_flavor, yogurt_type = yogurt_data(data_mer)
yogurt_flavor_bar(yogurt_flavor)

# %%
from graph import yogurt_type_pie
yogurt_type_pie(yogurt_type)
