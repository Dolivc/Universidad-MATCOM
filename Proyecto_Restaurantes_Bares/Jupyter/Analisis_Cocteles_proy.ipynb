# %%
from IPython.display import display, Image
img = Image(filename= "C:\\Users\\flaco\\Documents\\GitHub\\Universidad-MATCOM\\Proyecto_Restaurantes_Bares\\Jupyter\\15d10263e38eeb1b0df24eb93c4caaf8.jpg" )
display(img)

# %% [markdown]
# Carlos un apasionado de los cocteles cubanos a vivido toda su vida en La Habana. Ha tenido la suerte de probar una gran variedad de cocteles, pero siempre ha tenido preferencia por cuatro bebidas clasicas : la piña colada, el cuba libre, el mojito y el daiquiri. Inspirado por su amor a estas bebidas, Carlos se propone realizar un analisis en los distintos bares y restaurantes de La Habana. Su objetivo es descubrir si existen diferencias significativas en los precios de estos cocteles segun la ubicacion, el tipo de establecimiento y el tipo de coctel. Con su muestra de 231 restaurantes y bares, Carlos espera recopilar informacion valiosa y utilizar estos datos para responder sus preguntas y compartir sus hallazgos con otros amantes de los cocteles cubanos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from bibliotheque import data

# %%
from bibliotheque import conteo_rest_gen
dfy = conteo_rest_gen(data)
fig = px.bar(dfy, x = "Municipio", y = "Contador" , color = "Propiedad", color_discrete_map={"Particular": "mediumvioletred", "Estatal": "blueviolet", "Mipyme": "blue", "Proyecto de desarrollo local": "forestgreen", "ONG":"cyan", "Cooperativa": "green"})
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# Para profundizar en su analisis de los 231 restaurantes, Carlos decidio examinar los datos segun el tipo de propiedad y el municipio para comprender mejor las tendencias de los locales. Sus hallazgos revelaron que los restaurantes particulares son los que mas predominan en la ciudad, y que el municipio Playa tiene la mayor concentracion de este tipo de establecimientos. Esto se debe en parte a la popularidad creciente de las paladares en la gastronomia cubana. Ademas Carlos observo que el muinicipio de La Habana Vieja tiene una mayor proporcion de restaurantes estatales en comparacion con otros municipios. Pudo encontrar otros tipos de establecimiento, pero estos estaban concentrados en Plaza (a excepcion de una mipyme en la Habana Vieja). El proyecto de desarrollo local sin duda fue lo que mas llamo su atencion, ya que esta iniciativa se propone ayudar a mejora de esa localidad y para Carlos fue una pena no haber encontrado ningun otro local como este para su muestra.

# %%
from bibliotheque import contar_restaurant_dist_prop
df_result = contar_restaurant_dist_prop(data)
fig = px.bar(df_result, x = "Municipio", y = "Contador" , color = "Propiedad", color_discrete_map={"Particular": "mediumvioletred", "Estatal": "blueviolet", "Mipyme": "blue", "Proyecto de desarrollo local": "forestgreen", "ONG":"cyan", "Cooperativa": "green"})
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# Despues de analizar la informacion recopilada, Carlos observo que su muestra inicial de 231 restaurantes y bares se redujo a una muestra mas pequeña de establecimientos debido a que no todos ofertaban los cuatro cocteles en los que se centro su estudio. Esto muestra que aunque estas bebidas son populares y consideradas parte de la cultura gastronomica cubana no todos los establecimientos se centran en su oferta sobre todo aquellos mas alejados de las zonas que podriamos considerar mas visitadas por los turistas. Con esto hablamos de la preferencia del cliente, los propietarios de los locales pueden adaptar su oferta a las preferencias de estos. Si observan que los cocteles no son populares entre los clientes pueden elegir no incluirlos en su menu. Municipios como San Miguel, Arroyo Naranjo y el Cotorro, los restaurantes de su muestra no ofrecian ninguno de los cuatro cocteles, y la mayor concentracion de locales que las ofertan se encuentra en La Habana Vieja.

# %%
from bibliotheque import conteo_cerveza
cc = conteo_cerveza(data)
fig = px.histogram(cc, x = "Municipio", y = "Contador", color_discrete_sequence= ["pink"])
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# Carlos le intereso saber si existiria algun cambio en los numeros si probaba con los restaurantes que ofertaban cerveza en los tres municipios que mas restaurantes tenian de su muestra. Buscaba comparar la popularidad de los cocteles con la cerveza para determinar si existian diferencias significativas en su oferta y disponibilidad en los municipios. No le sorprendio ver el elevado numero de restaurantes que la ofertan en los tres municipios. Esto podria deberse a varios factores como el costo y la disponibilidad de cerveza en comparacion con los ingredientes mas especificos necesarios para la elaboracion de cocteles.

# %%
from bibliotheque import conteo_3_gen
c3g = conteo_3_gen(data)
fig = px.histogram(c3g, x = "Municipio", y = "Contador", color_discrete_sequence= ["#5b4381"])
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# Apoyandose a esta grafica que muestra el numero de restaurantes que ofertan los cocteles, al comparar con la grafica anterior Carlos observo una disminucion en el numero de restaurantes en comparacion con los que ofrecen cerveza. Esto indica que la cerveza es una opcion mas comun que los cocteles, y que la oferta de estos depende de las preferencias de sus consumidores, ya que La Habana Vieja es un lugar turistico por excelencia, por lo que el turismo puede sea la razon principal de que el consumo de cocteles se mantenga elevado en esta zona.

# %%
from bibliotheque import rest_com_3
rc3 = rest_com_3(data)
fig = px.histogram(rc3, x = "Municipio", y = "Contador", color_discrete_sequence= ["#30BFDD"])
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# Para profundizar en su investigacion sobre la disponibilidad de los cuatro cocteles, Carlos con la ayuda de la grafica anterior en donde analizo los restaurantes que ofertaban cocteles (La grafica color morado) y la segunda grafica (color azul) que presenta la cantidad de establecimientos en esos mismos municipios que ofertan en la carta los 4 cocteles. El proposito de este analisis fue determinar si existia una relacion entre la cantidad de restaurantes en un municipio y la probabilidad de encontrar un establecimiento que ofreciera todos los cocteles analizados. Al comparar las dos graficas, Carlos observo que existia una relacion entre ellas y es que concluyo que las probabilidades de encontrar un establecimiento que los ofertaran los 4 esta relacionada a la cantidad de restaurantes que tenga ese municipio. A medida que estos disminuyen, la posibilidad de que un lugar sirva todos los cocteles tambien lo hace.

# %%
from bibliotheque import Cantidad
from bibliotheque import Bebidas
colores = ["yellow", "lime", "green", "lawngreen"]
split = (0,0,0.1,0)
plt.pie(Cantidad, labels = Bebidas, autopct = "%0.1f%%", colors= colores, explode= split)
plt.axis("equal")
plt.show()

# %% [markdown]
# Una vez realizado el analisis de la muestra de restaurantes y bares que ofrecen los cuatro cocteles, Carlos concluyo que el mojito resulto ser el coctel mas ofertado, mientras que la piña colada tuvo el ultimo lugar en  frecuencia en los menus. Esto podria deberse a varios factores como que el mojito es un coctel emblematico de Cuba y muchos establecimientos pueden querer incluirlo en su carta como una bebida representativa del lugar. Ademas los ingredinetes del mojito como la menta, el ron y el azucar son relativamente faciles de conseguir. Por otro lado la piña colada aunque tambien es otra bebida popular, puede requerir de ingredientes mas costosos como la piña fresca y la crema de coco. Esto podria explicar parte de su poca frecuencia en los menus habaneros.

# %%
from IPython.display import display, Image
img = Image(filename= "C:\\Users\\flaco\\Documents\\GitHub\\Universidad-MATCOM\\Proyecto_Restaurantes_Bares\\Jupyter\\6fd50496a41e68cf24b5e3883ebd4c76.jpg" )
display(img)

# %% [markdown]
# ¿Cual es la mediana de cada coctel? ¿Existen diferencias significativas dependiendo de la propiedad del restaurante?

# %% [markdown]
# *Mediana Mojito*

# %%
from bibliotheque import media_coctel
mm = media_coctel(data,"Mojito")
fig = px.histogram(mm, x = "Municipio", y = "Mediana", color = "Propiedad", color_discrete_sequence=px.colors.qualitative.Dark24, barmode="group")
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# *Mediana Cuba Libre*

# %%
from bibliotheque import media_coctel
mm = media_coctel(data,"Cuba libre")
fig = px.histogram(mm, x = "Municipio", y = "Mediana", color = "Propiedad", barmode="group")
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %%
from IPython.display import display, Image
img = Image(filename= "C:\\Users\\flaco\\Documents\\GitHub\\Universidad-MATCOM\\Proyecto_Restaurantes_Bares\\Jupyter\\a840823867c93204dfb65688645b2ce0.jpg" )
display(img)

# %% [markdown]
# *Mediana Piña colada*

# %%
from bibliotheque import media_coctel
mm = media_coctel(data,"Pinha colada")
fig = px.histogram(mm, x = "Municipio", y = "Mediana", color = "Propiedad", color_discrete_sequence=px.colors.qualitative.Plotly_r, barmode="group")
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %%
from IPython.display import display, Image
img = Image(filename= "C:\\Users\\flaco\\Documents\\GitHub\\Universidad-MATCOM\\Proyecto_Restaurantes_Bares\\Jupyter\\68a62d8349236bae73b62a14f7f33330.jpg" )
display(img)

# %% [markdown]
# *Mediana Daiquiri*

# %%
from bibliotheque import media_coctel
mm = media_coctel(data,"Daiquiri")
fig = px.histogram(mm, x = "Municipio", y = "Mediana", color = "Propiedad", color_discrete_sequence=px.colors.qualitative.Alphabet_r, barmode="group")
fig.update_traces(marker_line_color =["Black"], marker_line_width = 1)
fig.show()

# %% [markdown]
# Carlos aprovechando del conocimiento del precio de los cocteles decidio realizar la mediana de cada uno y los ubico en una grafica, comenzando por el mojito, el cuba libre, la piña colada y el daiquiri. El objetivo de calcular la mediana era obtener una idea general del costo de esos cocteles en los distintos municipios de La Habana y ademas conocer que tanto variarian los precios de un tipo de propiedad a otra. Al observar los datos en las graficas Carlos observo que los precios mas elevados se ubicaban en la propiedad Mipyme en La Habana Vieja. En las cuatro graficas este fue el pico con el precio mas elevado. Tambien en la Habana Vieja ocurrio algo curioso y es que la mediana en los estatales es mas elevada que los particulares en este zona a excepcion de con el cuba libre donde es 200 pesos mas bajo. En conclusion los resultados mostraron diferencias significativas entre los diferentes tipos de establecimiento y los municipios.

# %%
from bibliotheque import var_dai
type_dai = var_dai(data)
dai = px.pie(type_dai, values = "Contador", names = "Coctel", color = "Coctel")
dai.show()

# %% [markdown]
# Carlos decidio investigar sobre las variantes del daiquiri, el objetivo era comprender mejor la popularidad de las variantes del daiquiri en La Habana. El resultaddo fue que las variantes no son tan populares como el daiquiri tradicional. De hecho el daiquiri frutal es la variante que mas se oferta, pero aun asi el numero de establecimientos que lo hacia es realmente pequeño, solo 18 locales.

# %%
from bibliotheque import cant_var_daiquiri
cvd = cant_var_daiquiri(data)
jjj = px.histogram(cvd, x = "Municipio", y = "Contador", color_discrete_sequence= ["limegreen"])
jjj.update_traces(marker_line_color =["Black"], marker_line_width = 1)
jjj.show()

# %% [markdown]
# En otro analisis Carlos ubico en una grafica la cantidad de variantes que se ofertan por municipio. Tanto en La Habana Vieja como en Plaza el contador marcaba que se ofertan 7 tipos diferentes de daiquiri, aun asi al juntar los resultados del analisis anterior y este, Carlos concluyo que las variantes del daiquiri no son tan populares como el daiquiri tradicional. Esto sugiere que las variantes de este coctel aun no han ganado mucha popularidad en los restaurantes de La Habana con solo un numero pequeño de ellos ofertandolas.

# %% [markdown]
# **En general con su analisis Carlos proporciono diversas conclusiones:**

# %% [markdown]
# ·El mojito es el coctel mas ofertado en los menus de los restaurantes.

# %% [markdown]
# ·Los establecimientos particulares son los que mas predominan en la ciudad, seguidos los estatales.

# %% [markdown]
# ·La oferta de cocteles varia entre los municipios, con la Habana Vieja siendo el municipio cuyos locales son los que mas ofertan los 4 cocteles simultaneamente.

# %% [markdown]
# ·La cerveza es mas popular que los cocteles.

# %% [markdown]
# ·Las variantes del daiquiri aun no han ganado mucha popularidad en la gastronomia cubana.

# %% [markdown]
# **Este analisis proporciono informacion que puede ser util para dueños de restaurantes y bares a la hora de diseñar su menu, asi como para los consumidores a la hora de elegir un lugar en el que consumir.**
